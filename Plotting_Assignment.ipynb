# %% [markdown]
# # **Project Plotting - Matplotlib Seaborn, Histograms and Boxplots**
#
# The most recent ASC23 considered four major systems-based tracks with a view to providing region-focused contributions to inform the global stocktake among them Cities, urban and rural settlements, infrastructure, and transport.
#
# In this assignment, you will be performing analysis more specifically on transport (vehicles and fuel efficiency).
#
# The dataset has been provided for you.
#
# You are tasked to make sense of this data that will later be used for AI purposes.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("fuel_econ.csv")

# %%
# Displaying the first 7 rows
df.head(12)
# Out:
#        id        make           model  year           VClass  \
# 0   32204      Nissan            GT-R  2013  Subcompact Cars
# 1   32205  Volkswagen              CC  2013     Compact Cars
# 2   32206  Volkswagen              CC  2013     Compact Cars
# 3   32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4   32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
# 5   32209       Lexus          GS 350  2013     Midsize Cars
# 6   32210       Lexus      GS 350 AWD  2013     Midsize Cars
# 7   32214     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 8   32215     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 9   32216     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 10  32217     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 11  32218  Volkswagen              CC  2013     Compact Cars
#
#                 drive              trans          fuelType  cylinders  displ  \
# 0     All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# ...

# %%
# to visualise the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3929 non-null   int64
#  1   make       3929 non-null   object
#  2   model      3929 non-null   object
#  3   year       3929 non-null   int64
#  4   VClass     3929 non-null   object
#  5   drive      3929 non-null   object
#  6   trans      3929 non-null   object
#  7   fuelType   3929 non-null   object
#  8   cylinders  3929 non-null   int64
#  9   displ      3929 non-null   float64
#  10  pv2        3929 non-null   int64
#  11  pv4        3929 non-null   int64
#  12  city       3929 non-null   float64
#  13  UCity      3929 non-null   float64
#  14  highway    3929 non-null   float64
#  15  UHighway   3929 non-null   float64
#  16  comb       3929 non-null   float64
#  17  co2        3929 non-null   int64
#  18  feScore    3929 non-null   int64
# ...

# %%
# prerequisite package imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# :We'll work with the fuel economy dataset in this workspace.
#
# Load the dataset and print at least 10 rows
#
# 1.   Load the dataset
# 2.   print atleast 10 rows of it

# %%
#YOUR CODE
df = pd.read_csv("fuel_econ.csv")
df.head(12)
# Out:
#        id        make           model  year           VClass  \
# 0   32204      Nissan            GT-R  2013  Subcompact Cars
# 1   32205  Volkswagen              CC  2013     Compact Cars
# 2   32206  Volkswagen              CC  2013     Compact Cars
# 3   32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4   32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
# 5   32209       Lexus          GS 350  2013     Midsize Cars
# 6   32210       Lexus      GS 350 AWD  2013     Midsize Cars
# 7   32214     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 8   32215     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 9   32216     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 10  32217     Hyundai   Genesis Coupe  2013  Subcompact Cars
# 11  32218  Volkswagen              CC  2013     Compact Cars
#
#                 drive              trans          fuelType  cylinders  displ  \
# 0     All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# ...

# %% [markdown]
# Play Around with Bin size as you create your Histogram
#
# [Bin size in Matplot Lib](https://www.geeksforgeeks.org/bin-size-in-matplotlib-histogram/)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  **Description**
# The dataset has a number of different statistics that describe fuel efficiency.
#
#
# **TO DO**:
# 1.   create a _histogram_ that depicts the distribution of carbon Dioxide
# 2.   Play  around with different bin width sizes to see what best depicts the data
#
# Create 2 more histograms based on columns of your choice

# %%
# Histogram that depicts the distribution of carbon Dioxide
plt.hist(df["co2"], bins=100)
plt.xlabel("CO2 Emissions")
plt.ylabel("Frequency")
plt.title("Distribution of CO2")
plt.show()

# %%
# Playing around with different bin sizes
plt.figure(figsize=(9, 6))
plt.hist(df["co2"], bins=30, color='brown', edgecolor="skyblue")
plt.xlabel("CO2 Emissions")
plt.ylabel("Frequency")
plt.title("Distribution of CO2")
plt.show()

# %%
# Playing around with different bin sizes (Equal bin width)
plt.hist(df["co2"], bins=[104, 204, 304, 404, 504, 604, 704], color='brown', edgecolor="skyblue")
plt.xlabel("CO2 Emissions")
plt.ylabel("Frequency")
plt.title("Distribution of CO2")
plt.show()

# %%
# Histogram based on ghgScore column
plt.hist(df["ghgScore"], bins=10, color="green", edgecolor="yellow")
plt.xlabel("ghg Emissions")
plt.ylabel("Frequency")
plt.title("Distribution of Green House Gases")
plt.show()

# %%
# Histogram based on displ column
plt.hist(df["displ"], edgecolor="brown")
plt.xlabel("displacement")
plt.ylabel("Frequency")
plt.title("Engine displacement in litres")
plt.show()

# %% [markdown]
# **TO DO: Write Code that will give you the following plot as below:**
#
# 1.   create a heat map of the data
# 2.Interpret the data - What story does the visualization tell?
#
# >
#
# Finally What Columns would you delete Drop if the target is the ghg score? Justify your Answer
#
#
#
#
#
# ---
#
# ![image.png](data:image/png;base64,...)

# %%
# Creating a heatmap of the data (without annotation)
plt.figure(figsize=(6, 5)) # (width, length)
columns = ["id", "year", "cylinders", "displ", "pv2", "pv4", "city", "UCity", "highway", "UHighway", "comb", "co2", "feScore", "ghgScore"]

df1 = df[columns]

# to show how closely related each column is
corre = df1.corr()

# annotation set to true shows the value of the correlaton for analysis
# vmin and vmax are parameters to specify the data range of values for the colormap
sns.heatmap(corre, cmap='RdYlBu')
plt.title("Heatmap")

# make x values slant
ax = plt.gca()
ax.tick_params(axis='x', labelrotation = 45)
plt.show()

# %%
# Creating a heatmap of the data (with annotation and colormap)
plt.figure(figsize=(11, 4)) #(10, 4) ---> (width, length)
columns = ["id", "year", "cylinders", "displ", "pv2", "pv4", "city", "UCity", "highway", "UHighway", "comb", "co2", "feScore", "ghgScore"]

df1 = df[columns]

# to show how closely related each column is
corre = df1.corr()

# annotation set to true shows the value of the correlaton for analysis
# vmin and vmax are parameters to specify the data range of values for the colormap
sns.heatmap(corre, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Heatmap")
plt.show()

# %% [markdown]
# ## **Data Interpretation**
#
# The heatmap Interpretation can be done based on Correlation Values or Colormap as seen in the image above.
#
#
#
# > **Positive correlation values indicate a direct relationship (as one variable increases, so does the other), while negative values indicate an inverse relationship (as one variable increases, the other decreases). Values close to 1 or -1 indicate strong correlations, whereas values close to 0 indicate weak or no correlation.**
#
#
#
# *Correlation Values Interpretation:*
# *  **Cylinders and CO2 Emissions (0.85):** This strong positive correlation shows that vehicles with more cylinders tend to have higher CO2 emissions. This is expected, as engines with more cylinders usually consume more fuel, leading to increased CO2 emissions.
#
# *  **Greenhouse Gas Score (ghgScore) and CO2 Emissions (-0.94):** The greenhouse gas score has a strong negative correlation with CO2 emissions. Higher CO2 emissions are associated with a lower greenhouse gas score, depicting the vehicle's larger environmental impact. With this info, we can say that ghgScore is negatively correlated, implying that both of them don't affect each other.
#
# *  **Year:** The weak correlation of the year with most variables shows that there isn't a strong trend towards more or less fuel efficiency over the years in this dataset. I can also interpret year to be that the cars being brand new doesn't really affect fuel efficiency. With this info, we can say that year has a low correlation to fuel efficiency.
#
# > **This ``` coolwarm ``` colormap visually shows the correlation values. It ranges from blue (indicating a strong negative correlation) to red (indicating a strong positive correlation).**
#
# *Colormap Interpretation:*
#
#
# 1. **Blue Shades:**
#
# * **Strong Negative Correlation (-1 to 0):** The blue shades represent negative correlations, with darker blues showing stronger negative relationships. For instance, displ (engine displacement) and feScore have a dark blue cell with a correlation value of -0.93, showing that as engine displacement increases, the fuel efficiency score decreases significantly.
#
# 2. **Red Shades:**
#
# * **Strong Positive Correlation (0 to +1):** The red shades indicate positive correlations, with darker reds showing stronger positive relationships. For example, the correlation between co2 and cylinders is 0.85, highlighted in a dark red cell, meaning that as the number of cylinders increases, CO2 emissions also rise.
#
# 3. **Neutral (White) Areas:**
#
# * **Weak or No Correlation (close to 0):** The cells with colours closer to white show weaker correlations, near zero, meaning little to no linear relationship between the variables. For example, the correlation between year and most other variables is close to 0, shown in lighter shades, depicting that the year does not significantly influence those variables in this dataset.

# %% [markdown]
# ---

# %% [markdown]
# Considering that the target is the **ghgScore**, I will drop **year**, **cylinders**, **displ**, **pv2**, and **pv4** columns because they have weak correlations/ less impact on **ghgScore** compared to other features like **city**, **UCity**, **highway**, **UHighway**, **comb**, **co2**, and **feScore**.
#
# For example, the correlation value between **year** and **ghgScore** is -0.15 (closer to zero) which shows that the year in which a vehicle was manufactured has a limited impact on its greenhouse gas emissions. On the other hand, **co2** and **feScore** have stronger correlations with **ghgScore**, showing they are more influential in determining a vehicle's greenhouse gas emissions.
